# %%
# First we will import the necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#  In this at first there are 4 empty rows we have to ignore or remove that. Therefore, we have use skiprows = 4.

df = pd.read_csv(r"C:\Users\sutha\Downloads\API_SP.POP.TOTL_DS2_en_csv_v2_19373\API_SP.POP.TOTL_DS2_en_csv_v2_19373.csv", skiprows = 4)
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130072080.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2016         2017         2018         2019  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 70 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
print("Columns Given in data:", df.columns)
# Out:
# Columns Given in data: Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'Unnamed: 69'],
#       dtype='object')

# %%
df.tail()
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    984846.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5532301.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  16440172.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3153729.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3809389.0
#
#            1961        1962        1963        1964        1965  ...  \
# 261   1011421.0   1036950.0   1062737.0   1090270.0   1120168.0  ...
# 262   5655232.0   5782221.0   5911135.0   6048006.0   6195593.0  ...
# 263  16908035.0  17418522.0  17954564.0  18511361.0  19089380.0  ...
# 264   3254086.0   3358099.0   3465907.0   3577017.0   3692086.0  ...
# 265   3930401.0   4055959.0   4185877.0   4320006.0   4458462.0  ...
#
#            2016        2017        2018        2019        2020        2021  \
# ...

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.154480e+08  1.170538e+08  1.192160e+08  1.218878e+08  1.245835e+08
# std    3.626523e+08  3.671660e+08  3.738303e+08  3.824608e+08  3.911397e+08
# min    2.715000e+03  2.970000e+03  3.264000e+03  3.584000e+03  3.922000e+03
# 25%    5.152028e+05  5.255230e+05  5.363018e+05  5.475875e+05  5.593638e+05
# 50%    3.659633e+06  3.747132e+06  3.831900e+06  3.919710e+06  4.010150e+06
# 75%    2.686293e+07  2.761326e+07  2.837302e+07  2.915448e+07  2.995223e+07
# max    3.021529e+09  3.062769e+09  3.117373e+09  3.184063e+09  3.251253e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.273111e+08  1.301581e+08  1.330127e+08  1.359425e+08  1.389705e+08
# ...

# %%
#  Now, we have to create Bar chart, line chart and Histogram for the given data.

# 1. Bar chart  - Let us select Year 2022.


missing_count = df['2022'].isna().sum()
print(f"Number of missing values in 2022: {missing_count}")

# Clean data
df_cleaned = df.dropna(subset=['2022'])
df_cleaned.loc[:, '2022'] = df_cleaned['2022'].astype(float)

plt.figure(figsize=(60, 12))  
plt.bar(df_cleaned['Country Name'], df_cleaned['2022'], color='skyblue')
plt.title("Total Population in 2022 (All Countries)", fontsize=20)
plt.xlabel("Country", fontsize=14)
plt.ylabel("Population", fontsize=14)
plt.xticks(rotation=90, fontsize=8)  
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Number of missing values in 2022: 1

# %%
#  This is for top 20 countries by population in 2022.

top_20_countries = df_cleaned.sort_values(by='2022', ascending=False).head(20)

plt.figure(figsize=(10, 6))  
plt.bar(top_20_countries['Country Name'], top_20_countries['2022'], color='skyblue')
plt.title("Top 20 Countries by Population in 2022", fontsize=16)
plt.xlabel("Country", fontsize=12)
plt.ylabel("Population", fontsize=12)
plt.xticks(rotation=90, fontsize=10)  
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#  In this I try to create TWO BAR CHARTS for the year 2012 and 2022 together with is interesting part to learn here.
#  Then, i have selected some countries to show the population in 2012 and 2022.

df_cleaned = df.dropna(subset=['2012', '2022'])
df_cleaned.loc['2012'] = df_cleaned['2012'].astype(float)
df_cleaned.loc['2022'] = df_cleaned['2022'].astype(float)

selected_countries = ['India', 'China', 'United States', 'Indonesia', 'Brazil', 'Pakistan', 'Nigeria']
selected_df = df_cleaned[df_cleaned['Country Name'].isin(selected_countries)]

countries = selected_df['Country Name']
pop_2012 = selected_df['2012']
pop_2022 = selected_df['2022']


import numpy as np
x = np.arange(len(countries))
bar_width = 0.35

# Plot side-by-side bars  --> New Interesting part to learn
plt.figure(figsize=(12, 6))
plt.bar(x - bar_width/2, pop_2012, width=bar_width, label='2012', color='orange')
plt.bar(x + bar_width/2, pop_2022, width=bar_width, label='2022', color='skyblue')


plt.title("Population Comparison (2012 vs 2022)", fontsize=16)
plt.xlabel("Country")
plt.ylabel("Population")
plt.xticks(x, countries, rotation=45)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# 2. Histogram - For Year 2022

year = '2022'
plt.figure(figsize=(10, 6))
plt.hist(df_cleaned[year], bins=30, color='orange', edgecolor='black')
plt.title(f"Distribution of Population Across Countries in {year}")
plt.xlabel("Population")
plt.ylabel("Number of Countries")
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
year = '2022'

top20 = df_cleaned[['Country Name', year]].sort_values(by=year, ascending=False).head(20)

plt.figure(figsize=(12, 8))
plt.barh(top20['Country Name'], top20[year], color='skyblue', edgecolor='black')
plt.title(f"Top 20 Most Populous Countries in {year}")
plt.xlabel("Population")
plt.ylabel("Country")
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
years = ['2012', '2022']

plt.figure(figsize=(10, 6))

plt.hist(df_cleaned['2012'], bins=30, color='blue', edgecolor='black', alpha=0.5, label='2012')
plt.hist(df_cleaned['2022'], bins=30, color='orange', edgecolor='black', alpha=0.5, label='2022')

plt.title("Distribution of Population Across Countries (2012 vs 2022)")
plt.xlabel("Population")
plt.ylabel("Number of Countries")

plt.legend()

plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()

plt.show()
